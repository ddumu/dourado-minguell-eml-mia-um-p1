# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ddumu/dourado-minguell-eml-mia-um-p1/blob/main/main.ipynb)

# %% [markdown]
# # Práctica sobre Aprendizaje por Refuerzo

# %% [markdown]
# Este es el punto de entrada a las experimentaciones realizadas para la práctica sobre Aprendizaje por Refuerzo de la asignatura Extensiones de Machine Learning del Máster Universitario en Inteligencia Artificial de la Universidad de Murcia.
#
# En este notebook, se proporciona un enlace para cada una de las partes de la práctica: el bandido de k-brazos y entornos complejos. Desde cada uno de ellos, se podrá navegar a experimentos específicos de la misma manera.

# %% [markdown]
# ## El bandido de k-brazos

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ddumu/dourado-minguell-eml-mia-um-p1/blob/main/k_brazos/main.ipynb)

# %% [markdown]
# ## Entornos complejos

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ddumu/dourado-minguell-eml-mia-um-p1/blob/main/Entornos_Complejos/main.ipynb)
